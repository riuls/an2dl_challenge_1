# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Homework1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Homework1

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
import matplotlib.pyplot as plt
from random import randint

# %%
seed = 45
import os
import random

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
def load_data(folder="public_data.npz", resolution=96, head_only=False):
    images = []

    loaded = np.load(folder, allow_pickle=True)

    # Iterate through files in the specified folder
    for i, img in enumerate(loaded['data']):
        # Normalize image pixel values to a float range [0, 1]
        #img = (img / 255).astype(np.float32)

        # Convert image from BGR to RGB
        #img = img[...,::-1]

        # Make the image dataset squared
        dim = min(img.shape[:-1])
        img = img[(img.shape[0]-dim)//2:(img.shape[0]+dim)//2, (img.shape[1]-dim)//2:(img.shape[1]+dim)//2, :]

        # Resize the image to 224x224 pixels
        #img = tfkl.Resizing(224, 224)(img)
        img = tfkl.Resizing(resolution, resolution)(img)

        if img is not None:
            images.append(img)

        if (head_only and i == 9):
           break

    labels = loaded['labels']
    loaded.close()

    if (head_only):
       labels = labels[:10]

    y = LabelEncoder().fit_transform(labels)
    y = tfk.utils.to_categorical(y, 2)

    return np.array(images), y




def display_random_images(X, y, num_img=10):
  # Create subplots for displaying items
  fig, axes = plt.subplots(2, num_img//2, figsize=(20, 9))
  for i in range(num_img):
      image = randint(0, X.shape[0] - 1)

      ax = axes[i%2, i%num_img//2]
      ax.imshow(np.clip(X[image], 0, 255))  # Display clipped item images
      ax.text(0.5, -0.1, str(image) + ' ' + str(y[image]), size=12, ha="center", transform=ax.transAxes)
      ax.axis('off')
  plt.tight_layout()
  plt.show()




def delete_outliers(X, y):
  shrek = 137
  trololo = 5143

  new_X = []
  new_y = []

  num_outliers = 0

  for i, sample in enumerate(X):
    if (not (np.array_equal(sample, X[shrek]) or np.array_equal(sample, X[trololo]))):
      new_X.append(sample)
      new_y.append(y[i])
    else:
      num_outliers += 1

  return np.array(new_X), np.array(new_y), num_outliers

# %%
X, y = load_data('public_data.npz')
X, y, num_outliers = delete_outliers(X, y)

# %%
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=500, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train_0, y_val = train_test_split(X_train_val, y_train_val, test_size=500, stratify=np.argmax(y_train_val,axis=1))

print(X_train.shape, y_train_0.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (4004, 96, 96, 3) (4004, 2)
# (500, 96, 96, 3) (500, 2)
# (500, 96, 96, 3) (500, 2)

# %%
augment1 = tf.keras.Sequential([
    tfkl.RandomFlip(),
    tfkl.RandomTranslation(height_factor = (-0.3,0.1), width_factor = (-0.1,0.3), fill_mode = 'reflect'),
    tfkl.RandomZoom(0.4, fill_mode = 'reflect'),
    tfkl.RandomBrightness(0.1, value_range=(0,255)),
])

augment2 = tf.keras.Sequential([
    tfkl.RandomFlip(),
    tfkl.RandomZoom(0.2, fill_mode = 'reflect'),
    tfkl.RandomBrightness(0.3, value_range=(0,255)),
    tfkl.RandomRotation((-1,1), fill_mode = 'reflect'),
])

new_X_train_1 = augment1(X_train[np.where((y_train_0[:, 0] == 0) & (y_train_0[:, 1] == 1))])
augmented_X_train_2 = augment2(X_train)
augmented_X_train_1 = augment1(augmented_X_train_2)

X_train = np.append(X_train ,augmented_X_train_2, axis = 0)
X_train = np.append(X_train ,augmented_X_train_1, axis = 0)
X_train = np.append(X_train ,new_X_train_1, axis = 0)

y_train = np.append(y_train_0, y_train_0, axis = 0)
y_train = np.append(y_train, y_train_0, axis = 0)
for k in range(new_X_train_1.shape[0]):
    y_train = np.append(y_train, [[0,1]], axis = 0)

# %%
# Define key model parameters
input_shape = X_train.shape[1:]  # Input shape for the model
output_shape = y_train.shape[1]  # Output shape for the model
batch_size = 16                # Batch size for training, always a power of 2!!
epochs = 400

# %%
mobile = tfk.applications.ConvNeXtTiny(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    include_preprocessing=True,
    pooling='avg',
)
mobile.trainable = False

# %%
inputs = tfk.Input(shape=input_shape)
# Connect MobileNetV2 to the input
x = mobile(inputs)
x = tfkl.Dropout(rate = 1/5)(x)
x = tfkl.Dense(64)(x)
#x = tfkl.BatchNormalization()(x)
x = tfkl.Activation('relu')(x)
x = tfkl.Dropout(rate = 1/7)(x)
x = tfkl.Dense(64)(x)
#x = tfkl.BatchNormalization()(x)
x = tfkl.Activation('relu')(x)
x = tfkl.Dropout(rate = 1/7)(x)
x = tfkl.Dense(16)(x)
#x = tfkl.BatchNormalization()(x)
x = tfkl.Activation('relu')(x)
x = tfkl.Dropout(rate = 1/7)(x)
# Add a Dense layer with 2 units and softmax activation as the classifier
outputs = tfkl.Dense(2, activation='softmax')(x)

# Create a Model connecting input and output
model_1 = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model with Categorical Cross-Entropy loss and Adam optimizer
model_1.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.AdamW(learning_rate=4e-3, weight_decay=8e-5), metrics=['accuracy'])

# Display model summary
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  convnext_tiny (Functional)  (None, 768)               27820128
#
#  dropout (Dropout)           (None, 768)               0
#
#  dense (Dense)               (None, 64)                49216
#
#  activation (Activation)     (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 16)                1040
#
#  activation_2 (Activation)   (None, 16)                0
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 27874578 (106.33 MB)
# Trainable params: 54450 (212.70 KB)
# Non-trainable params: 27820128 (106.13 MB)
# _________________________________________________________________

# %%
history = model_1.fit(
    x = X_train, # We need to apply the preprocessing thought for the MobileNetV2 network
    y = y_train,
    batch_size = 16,
    epochs = 400,
    validation_data = (X_val, y_val), # We need to apply the preprocessing thought for the MobileNetV2 network
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=30, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0
# Epoch 118/400
# 846/846 [==============================] - 35s 42ms/step - loss: 0.2585 - accuracy: 0.8864 - val_loss: 0.3988 - val_accuracy: 0.8540 - lr: 0.0014
# Epoch 119/400
# 846/846 [==============================] - 36s 42ms/step - loss: 0.2619 - accuracy: 0.8860 - val_loss: 0.3941 - val_accuracy: 0.8480 - lr: 0.0014

# %%
# Evaluate the model on the test set
test_accuracy = model_1.evaluate(X_test,y_test,verbose=0)[-1]
print('Test set accuracy %.4f' % test_accuracy)
# Out:
# Test set accuracy 0.8640

# %%
model_1.save('convnext_nobatchnorm_NO_INVERSION')

# %%
del model_1

# %%
ft_model = tfk.models.load_model('convnext_nobatchnorm_NO_INVERSION')

# %%
ft_model.get_layer('convnext_tiny').trainable = True

# %%
print(len(ft_model.get_layer('convnext_tiny').layers))
# Out:
# 152

# %%
ft_model.get_layer('convnext_tiny').summary()
# Out:
# Model: "convnext_tiny"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  convnext_tiny_prestem_norm  (None, 96, 96, 3)            0         ['input_1[0][0]']
#  alization (Normalization)
#
#  convnext_tiny_stem (Sequen  (None, 24, 24, 96)           4896      ['convnext_tiny_prestem_normal
#  tial)                                                              ization[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           4800      ['convnext_tiny_stem[0][0]']
#  k_0_depthwise_conv (Conv2D
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           192       ['convnext_tiny_stage_0_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 384)          0         ['convnext_tiny_stage_0_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           96        ['convnext_tiny_stage_0_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           0         ['convnext_tiny_stage_0_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 24, 24, 96)           0         ['convnext_tiny_stem[0][0]',
#  Lambda)                                                             'convnext_tiny_stage_0_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           4800      ['tf.__operators__.add[0][0]']
#  k_1_depthwise_conv (Conv2D
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           192       ['convnext_tiny_stage_0_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 384)          0         ['convnext_tiny_stage_0_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           96        ['convnext_tiny_stage_0_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           0         ['convnext_tiny_stage_0_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 24, 24, 96)           0         ['tf.__operators__.add[0][0]',
#  OpLambda)                                                           'convnext_tiny_stage_0_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           4800      ['tf.__operators__.add_1[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           192       ['convnext_tiny_stage_0_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 384)          37248     ['convnext_tiny_stage_0_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 384)          0         ['convnext_tiny_stage_0_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           36960     ['convnext_tiny_stage_0_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           96        ['convnext_tiny_stage_0_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_0_bloc  (None, 24, 24, 96)           0         ['convnext_tiny_stage_0_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 24, 24, 96)           0         ['tf.__operators__.add_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_0_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 12, 12, 192)          74112     ['tf.__operators__.add_2[0][0]
#  _block_0 (Sequential)                                              ']
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          9600      ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_0[0][0]']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          384       ['convnext_tiny_stage_1_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 768)          0         ['convnext_tiny_stage_1_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          192       ['convnext_tiny_stage_1_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          0         ['convnext_tiny_stage_1_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 12, 12, 192)          0         ['convnext_tiny_downsampling_b
#  OpLambda)                                                          lock_0[0][0]',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          9600      ['tf.__operators__.add_3[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          384       ['convnext_tiny_stage_1_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 768)          0         ['convnext_tiny_stage_1_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          192       ['convnext_tiny_stage_1_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          0         ['convnext_tiny_stage_1_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 12, 12, 192)          0         ['tf.__operators__.add_3[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          9600      ['tf.__operators__.add_4[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          384       ['convnext_tiny_stage_1_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 768)          148224    ['convnext_tiny_stage_1_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 768)          0         ['convnext_tiny_stage_1_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          147648    ['convnext_tiny_stage_1_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          192       ['convnext_tiny_stage_1_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_1_bloc  (None, 12, 12, 192)          0         ['convnext_tiny_stage_1_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 12, 12, 192)          0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_1_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 6, 6, 384)            295680    ['tf.__operators__.add_5[0][0]
#  _block_1 (Sequential)                                              ']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_1[0][0]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 6, 6, 384)            0         ['convnext_tiny_downsampling_b
#  OpLambda)                                                          lock_1[0][0]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['tf.__operators__.add_6[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 6, 6, 384)            0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['tf.__operators__.add_7[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_8 (TF  (None, 6, 6, 384)            0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     2_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['tf.__operators__.add_8[0][0]
#  k_3_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_3_layernorm (LayerNormal                                         3_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_3_pointwise_conv_1 (Dens                                         3_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_3_gelu (Activation)                                              3_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_3_pointwise_conv_2 (Dens                                         3_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_3_layer_scale (LayerScal                                         3_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_3_identity (Activation)                                          3_layer_scale[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 6, 6, 384)            0         ['tf.__operators__.add_8[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     3_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['tf.__operators__.add_9[0][0]
#  k_4_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_4_layernorm (LayerNormal                                         4_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_4_pointwise_conv_1 (Dens                                         4_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_4_gelu (Activation)                                              4_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_4_pointwise_conv_2 (Dens                                         4_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_4_layer_scale (LayerScal                                         4_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_4_identity (Activation)                                          4_layer_scale[0][0]']
#
#  tf.__operators__.add_10 (T  (None, 6, 6, 384)            0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     4_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['tf.__operators__.add_10[0][0
#  k_5_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_5_layernorm (LayerNormal                                         5_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_5_pointwise_conv_1 (Dens                                         5_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_5_gelu (Activation)                                              5_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_5_pointwise_conv_2 (Dens                                         5_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_5_layer_scale (LayerScal                                         5_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_5_identity (Activation)                                          5_layer_scale[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 6, 6, 384)            0         ['tf.__operators__.add_10[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     5_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['tf.__operators__.add_11[0][0
#  k_6_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_6_layernorm (LayerNormal                                         6_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_6_pointwise_conv_1 (Dens                                         6_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_6_gelu (Activation)                                              6_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_6_pointwise_conv_2 (Dens                                         6_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_6_layer_scale (LayerScal                                         6_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_6_identity (Activation)                                          6_layer_scale[0][0]']
#
#  tf.__operators__.add_12 (T  (None, 6, 6, 384)            0         ['tf.__operators__.add_11[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     6_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['tf.__operators__.add_12[0][0
#  k_7_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_7_layernorm (LayerNormal                                         7_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_7_pointwise_conv_1 (Dens                                         7_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_7_gelu (Activation)                                              7_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_7_pointwise_conv_2 (Dens                                         7_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_7_layer_scale (LayerScal                                         7_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_7_identity (Activation)                                          7_layer_scale[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 6, 6, 384)            0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     7_identity[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            19200     ['tf.__operators__.add_13[0][0
#  k_8_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            768       ['convnext_tiny_stage_2_block_
#  k_8_layernorm (LayerNormal                                         8_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           591360    ['convnext_tiny_stage_2_block_
#  k_8_pointwise_conv_1 (Dens                                         8_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 1536)           0         ['convnext_tiny_stage_2_block_
#  k_8_gelu (Activation)                                              8_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            590208    ['convnext_tiny_stage_2_block_
#  k_8_pointwise_conv_2 (Dens                                         8_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            384       ['convnext_tiny_stage_2_block_
#  k_8_layer_scale (LayerScal                                         8_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_2_bloc  (None, 6, 6, 384)            0         ['convnext_tiny_stage_2_block_
#  k_8_identity (Activation)                                          8_layer_scale[0][0]']
#
#  tf.__operators__.add_14 (T  (None, 6, 6, 384)            0         ['tf.__operators__.add_13[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_2_block_
#                                                                     8_identity[0][0]']
#
#  convnext_tiny_downsampling  (None, 3, 3, 768)            1181184   ['tf.__operators__.add_14[0][0
#  _block_2 (Sequential)                                              ]']
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            38400     ['convnext_tiny_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_2[0][0]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            768       ['convnext_tiny_stage_3_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            0         ['convnext_tiny_stage_3_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_15 (T  (None, 3, 3, 768)            0         ['convnext_tiny_downsampling_b
#  FOpLambda)                                                         lock_2[0][0]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     0_identity[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            38400     ['tf.__operators__.add_15[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            768       ['convnext_tiny_stage_3_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            0         ['convnext_tiny_stage_3_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_16 (T  (None, 3, 3, 768)            0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     1_identity[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            38400     ['tf.__operators__.add_16[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            1536      ['convnext_tiny_stage_3_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 3072)           2362368   ['convnext_tiny_stage_3_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 3072)           0         ['convnext_tiny_stage_3_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            2360064   ['convnext_tiny_stage_3_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            768       ['convnext_tiny_stage_3_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_tiny_stage_3_bloc  (None, 3, 3, 768)            0         ['convnext_tiny_stage_3_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_17 (T  (None, 3, 3, 768)            0         ['tf.__operators__.add_16[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_tiny_stage_3_block_
#                                                                     2_identity[0][0]']
#
#  global_average_pooling2d (  (None, 768)                  0         ['tf.__operators__.add_17[0][0
#  GlobalAveragePooling2D)                                            ]']
#
#  layer_normalization (Layer  (None, 768)                  1536      ['global_average_pooling2d[0][
#  Normalization)                                                     0]']
#
# ==================================================================================================
# Total params: 27820128 (106.13 MB)
# Trainable params: 27820128 (106.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Freeze first N layers
N = 10    # last block
for i, layer in enumerate(ft_model.get_layer('convnext_tiny').layers[:-N]):
  layer.trainable=False

# %%
for i, layer in enumerate(ft_model.get_layer('convnext_tiny').layers):
  print(layer.name, layer.trainable)
# Out:
# input_1 False
# convnext_tiny_prestem_normalization False
# convnext_tiny_stem False
# convnext_tiny_stage_0_block_0_depthwise_conv False
# convnext_tiny_stage_0_block_0_layernorm False
# convnext_tiny_stage_0_block_0_pointwise_conv_1 False
# convnext_tiny_stage_0_block_0_gelu False
# convnext_tiny_stage_0_block_0_pointwise_conv_2 False
# convnext_tiny_stage_0_block_0_layer_scale False
# convnext_tiny_stage_0_block_0_identity False
# tf.__operators__.add False
# convnext_tiny_stage_0_block_1_depthwise_conv False
# convnext_tiny_stage_0_block_1_layernorm False
# convnext_tiny_stage_0_block_1_pointwise_conv_1 False
# convnext_tiny_stage_0_block_1_gelu False
# convnext_tiny_stage_0_block_1_pointwise_conv_2 False
# convnext_tiny_stage_0_block_1_layer_scale False
# convnext_tiny_stage_0_block_1_identity False
# tf.__operators__.add_1 False
# convnext_tiny_stage_0_block_2_depthwise_conv False
# convnext_tiny_stage_0_block_2_layernorm False
# convnext_tiny_stage_0_block_2_pointwise_conv_1 False
# convnext_tiny_stage_0_block_2_gelu False
# convnext_tiny_stage_0_block_2_pointwise_conv_2 False
# convnext_tiny_stage_0_block_2_layer_scale False
# convnext_tiny_stage_0_block_2_identity False
# tf.__operators__.add_2 False
# convnext_tiny_downsampling_block_0 False
# convnext_tiny_stage_1_block_0_depthwise_conv False
# convnext_tiny_stage_1_block_0_layernorm False
# convnext_tiny_stage_1_block_0_pointwise_conv_1 False
# convnext_tiny_stage_1_block_0_gelu False
# convnext_tiny_stage_1_block_0_pointwise_conv_2 False
# convnext_tiny_stage_1_block_0_layer_scale False
# convnext_tiny_stage_1_block_0_identity False
# tf.__operators__.add_3 False
# convnext_tiny_stage_1_block_1_depthwise_conv False
# convnext_tiny_stage_1_block_1_layernorm False
# convnext_tiny_stage_1_block_1_pointwise_conv_1 False
# convnext_tiny_stage_1_block_1_gelu False
# convnext_tiny_stage_1_block_1_pointwise_conv_2 False
# convnext_tiny_stage_1_block_1_layer_scale False
# convnext_tiny_stage_1_block_1_identity False
# tf.__operators__.add_4 False
# convnext_tiny_stage_1_block_2_depthwise_conv False
# convnext_tiny_stage_1_block_2_layernorm False
# convnext_tiny_stage_1_block_2_pointwise_conv_1 False
# convnext_tiny_stage_1_block_2_gelu False
# convnext_tiny_stage_1_block_2_pointwise_conv_2 False
# convnext_tiny_stage_1_block_2_layer_scale False
# convnext_tiny_stage_1_block_2_identity False
# tf.__operators__.add_5 False
# convnext_tiny_downsampling_block_1 False
# convnext_tiny_stage_2_block_0_depthwise_conv False
# convnext_tiny_stage_2_block_0_layernorm False
# convnext_tiny_stage_2_block_0_pointwise_conv_1 False
# convnext_tiny_stage_2_block_0_gelu False
# convnext_tiny_stage_2_block_0_pointwise_conv_2 False
# convnext_tiny_stage_2_block_0_layer_scale False
# convnext_tiny_stage_2_block_0_identity False
# tf.__operators__.add_6 False
# convnext_tiny_stage_2_block_1_depthwise_conv False
# convnext_tiny_stage_2_block_1_layernorm False
# convnext_tiny_stage_2_block_1_pointwise_conv_1 False
# convnext_tiny_stage_2_block_1_gelu False
# convnext_tiny_stage_2_block_1_pointwise_conv_2 False
# convnext_tiny_stage_2_block_1_layer_scale False
# convnext_tiny_stage_2_block_1_identity False
# tf.__operators__.add_7 False
# convnext_tiny_stage_2_block_2_depthwise_conv False
# convnext_tiny_stage_2_block_2_layernorm False
# convnext_tiny_stage_2_block_2_pointwise_conv_1 False
# convnext_tiny_stage_2_block_2_gelu False
# convnext_tiny_stage_2_block_2_pointwise_conv_2 False
# convnext_tiny_stage_2_block_2_layer_scale False
# convnext_tiny_stage_2_block_2_identity False
# tf.__operators__.add_8 False
# convnext_tiny_stage_2_block_3_depthwise_conv False
# convnext_tiny_stage_2_block_3_layernorm False
# convnext_tiny_stage_2_block_3_pointwise_conv_1 False
# convnext_tiny_stage_2_block_3_gelu False
# convnext_tiny_stage_2_block_3_pointwise_conv_2 False
# convnext_tiny_stage_2_block_3_layer_scale False
# convnext_tiny_stage_2_block_3_identity False
# tf.__operators__.add_9 False
# convnext_tiny_stage_2_block_4_depthwise_conv False
# convnext_tiny_stage_2_block_4_layernorm False
# convnext_tiny_stage_2_block_4_pointwise_conv_1 False
# convnext_tiny_stage_2_block_4_gelu False
# convnext_tiny_stage_2_block_4_pointwise_conv_2 False
# convnext_tiny_stage_2_block_4_layer_scale False
# convnext_tiny_stage_2_block_4_identity False
# tf.__operators__.add_10 False
# convnext_tiny_stage_2_block_5_depthwise_conv False
# convnext_tiny_stage_2_block_5_layernorm False
# convnext_tiny_stage_2_block_5_pointwise_conv_1 False
# convnext_tiny_stage_2_block_5_gelu False
# convnext_tiny_stage_2_block_5_pointwise_conv_2 False
# convnext_tiny_stage_2_block_5_layer_scale False
# convnext_tiny_stage_2_block_5_identity False
# tf.__operators__.add_11 False
# convnext_tiny_stage_2_block_6_depthwise_conv False
# convnext_tiny_stage_2_block_6_layernorm False
# convnext_tiny_stage_2_block_6_pointwise_conv_1 False
# convnext_tiny_stage_2_block_6_gelu False
# convnext_tiny_stage_2_block_6_pointwise_conv_2 False
# convnext_tiny_stage_2_block_6_layer_scale False
# convnext_tiny_stage_2_block_6_identity False
# tf.__operators__.add_12 False
# convnext_tiny_stage_2_block_7_depthwise_conv False
# convnext_tiny_stage_2_block_7_layernorm False
# convnext_tiny_stage_2_block_7_pointwise_conv_1 False
# convnext_tiny_stage_2_block_7_gelu False
# convnext_tiny_stage_2_block_7_pointwise_conv_2 False
# convnext_tiny_stage_2_block_7_layer_scale False
# convnext_tiny_stage_2_block_7_identity False
# tf.__operators__.add_13 False
# convnext_tiny_stage_2_block_8_depthwise_conv False
# convnext_tiny_stage_2_block_8_layernorm False
# convnext_tiny_stage_2_block_8_pointwise_conv_1 False
# convnext_tiny_stage_2_block_8_gelu False
# convnext_tiny_stage_2_block_8_pointwise_conv_2 False
# convnext_tiny_stage_2_block_8_layer_scale False
# convnext_tiny_stage_2_block_8_identity False
# tf.__operators__.add_14 False
# convnext_tiny_downsampling_block_2 False
# convnext_tiny_stage_3_block_0_depthwise_conv False
# convnext_tiny_stage_3_block_0_layernorm False
# convnext_tiny_stage_3_block_0_pointwise_conv_1 False
# convnext_tiny_stage_3_block_0_gelu False
# convnext_tiny_stage_3_block_0_pointwise_conv_2 False
# convnext_tiny_stage_3_block_0_layer_scale False
# convnext_tiny_stage_3_block_0_identity False
# tf.__operators__.add_15 False
# convnext_tiny_stage_3_block_1_depthwise_conv False
# convnext_tiny_stage_3_block_1_layernorm False
# convnext_tiny_stage_3_block_1_pointwise_conv_1 False
# convnext_tiny_stage_3_block_1_gelu False
# convnext_tiny_stage_3_block_1_pointwise_conv_2 False
# convnext_tiny_stage_3_block_1_layer_scale False
# convnext_tiny_stage_3_block_1_identity False
# tf.__operators__.add_16 False
# convnext_tiny_stage_3_block_2_depthwise_conv True
# convnext_tiny_stage_3_block_2_layernorm True
# convnext_tiny_stage_3_block_2_pointwise_conv_1 True
# convnext_tiny_stage_3_block_2_gelu True
# convnext_tiny_stage_3_block_2_pointwise_conv_2 True
# convnext_tiny_stage_3_block_2_layer_scale True
# convnext_tiny_stage_3_block_2_identity True
# tf.__operators__.add_17 True
# global_average_pooling2d True
# layer_normalization True

# %%
ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.AdamW(learning_rate=1e-4, weight_decay=3.5e-5), metrics='accuracy')

# %%
history = ft_model.fit(
    x = X_train, # We need to apply the preprocessing thought for the MobileNetV2 network
    y = y_train,
    batch_size = 16,
    epochs = 400,
    validation_data = (X_val, y_val), # We need to apply the preprocessing thought for the MobileNetV2 network
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=15, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.9, patience = 8, min_lr = 2e-6)
    ]
).history
# Out:
# Epoch 1/400
# 846/846 [==============================] - 68s 62ms/step - loss: 0.4823 - accuracy: 0.7976 - val_loss: 0.2528 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 2/400
# 846/846 [==============================] - 46s 54ms/step - loss: 0.3967 - accuracy: 0.8222 - val_loss: 0.2381 - val_accuracy: 0.9080 - lr: 1.0000e-04
# Epoch 3/400
# 846/846 [==============================] - 44s 52ms/step - loss: 0.3548 - accuracy: 0.8434 - val_loss: 0.2452 - val_accuracy: 0.8920 - lr: 1.0000e-04
# Epoch 4/400
# 846/846 [==============================] - 44s 52ms/step - loss: 0.3252 - accuracy: 0.8568 - val_loss: 0.2451 - val_accuracy: 0.9080 - lr: 1.0000e-04
# Epoch 5/400
# 846/846 [==============================] - 44s 52ms/step - loss: 0.2944 - accuracy: 0.8713 - val_loss: 0.2294 - val_accuracy: 0.8980 - lr: 1.0000e-04
# Epoch 6/400
# 846/846 [==============================] - 44s 52ms/step - loss: 0.2605 - accuracy: 0.8865 - val_loss: 0.2304 - val_accuracy: 0.9160 - lr: 1.0000e-04
# Epoch 7/400
# 846/846 [==============================] - 44s 52ms/step - loss: 0.2322 - accuracy: 0.9020 - val_loss: 0.2127 - val_accuracy: 0.9180 - lr: 1.0000e-04
# Epoch 8/400
# 846/846 [==============================] - 44s 52ms/step - loss: 0.2021 - accuracy: 0.9151 - val_loss: 0.2382 - val_accuracy: 0.9100 - lr: 1.0000e-04
# Epoch 9/400
# 846/846 [==============================] - 44s 52ms/step - loss: 0.1804 - accuracy: 0.9257 - val_loss: 0.2586 - val_accuracy: 0.9120 - lr: 1.0000e-04
# Epoch 10/400
# 846/846 [==============================] - 44s 51ms/step - loss: 0.1549 - accuracy: 0.9363 - val_loss: 0.2430 - val_accuracy: 0.9120 - lr: 1.0000e-04
# Epoch 11/400
# 846/846 [==============================] - 44s 52ms/step - loss: 0.1348 - accuracy: 0.9472 - val_loss: 0.2455 - val_accuracy: 0.9020 - lr: 1.0000e-04
# Epoch 12/400
# 846/846 [==============================] - 46s 55ms/step - loss: 0.1178 - accuracy: 0.9522 - val_loss: 0.2798 - val_accuracy: 0.9140 - lr: 1.0000e-04
# Epoch 13/400
# 846/846 [==============================] - 43s 51ms/step - loss: 0.1021 - accuracy: 0.9581 - val_loss: 0.3028 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 14/400
# 846/846 [==============================] - 38s 45ms/step - loss: 0.0907 - accuracy: 0.9673 - val_loss: 0.3483 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 15/400
# 846/846 [==============================] - 39s 46ms/step - loss: 0.0728 - accuracy: 0.9725 - val_loss: 0.3823 - val_accuracy: 0.8980 - lr: 1.0000e-04
# Epoch 16/400
# 846/846 [==============================] - 39s 46ms/step - loss: 0.0617 - accuracy: 0.9752 - val_loss: 0.4420 - val_accuracy: 0.8980 - lr: 9.0000e-05
# Epoch 17/400
# 846/846 [==============================] - 37s 44ms/step - loss: 0.0484 - accuracy: 0.9815 - val_loss: 0.4694 - val_accuracy: 0.8960 - lr: 9.0000e-05
# Epoch 18/400
# 846/846 [==============================] - 38s 45ms/step - loss: 0.0459 - accuracy: 0.9833 - val_loss: 0.5285 - val_accuracy: 0.8980 - lr: 9.0000e-05
# Epoch 19/400
# 846/846 [==============================] - 40s 47ms/step - loss: 0.0411 - accuracy: 0.9848 - val_loss: 0.4976 - val_accuracy: 0.9000 - lr: 9.0000e-05
# Epoch 20/400
# 846/846 [==============================] - 38s 45ms/step - loss: 0.0348 - accuracy: 0.9888 - val_loss: 0.5879 - val_accuracy: 0.9020 - lr: 9.0000e-05
# Epoch 21/400
# 846/846 [==============================] - 39s 46ms/step - loss: 0.0308 - accuracy: 0.9891 - val_loss: 0.5891 - val_accuracy: 0.9080 - lr: 9.0000e-05
# Epoch 22/400
# 846/846 [==============================] - 38s 45ms/step - loss: 0.0304 - accuracy: 0.9891 - val_loss: 0.6559 - val_accuracy: 0.9020 - lr: 9.0000e-05

# %%
ft_model.save('convnext_finetuned_nobatchnorm_NO_INVERSION')

# %%
ft_model.evaluate(X_test,y_test)
# Out:
# 16/16 [==============================] - 5s 163ms/step - loss: 0.2381 - accuracy: 0.9040
# [0.23812024295330048, 0.9039999842643738]

# %%
X_test
# Out:
# array([[[[ 74., 124.,  39.],
#          [ 54., 103.,  21.],
#          [ 59., 105.,  30.],
#          ...,
#          [128., 148.,  87.],
#          [126., 146.,  85.],
#          [141., 161., 100.]],
#
#         [[ 79., 129.,  44.],
#          [ 61., 110.,  28.],
#          [ 60., 104.,  29.],
#          ...,
#          [136., 156.,  97.],
#          [145., 165., 106.],
#          [162., 182., 121.]],
#
#         [[ 73., 118.,  37.],
#          [ 68., 112.,  33.],
#          [ 62., 106.,  31.],
#          ...,
#          [135., 156., 100.],
#          [112., 133.,  77.],
#          [157., 178., 121.]],
#
#         ...,
#
#         [[151., 184., 115.],
#          [151., 184., 115.],
#          [151., 184., 113.],
#          ...,
#          [153., 184., 125.],
#          [145., 176., 119.],
#          [150., 181., 124.]],
#
#         [[148., 181., 112.],
#          [148., 181., 112.],
#          [145., 178., 107.],
#          ...,
#          [139., 170., 110.],
#          [141., 172., 115.],
#          [132., 163., 106.]],
#
#         [[142., 175., 106.],
#          [142., 175., 106.],
#          [142., 175., 104.],
#          ...,
#          [137., 168., 108.],
#          [133., 164., 107.],
#          [119., 150.,  93.]]],
#
#
#        [[[ 24.,  58.,   7.],
#          [ 18.,  52.,   1.],
#          [ 20.,  53.,   6.],
#          ...,
#          [100., 141.,  73.],
#          [112., 153.,  85.],
#          [118., 159.,  91.]],
#
#         [[ 20.,  52.,   2.],
#          [ 16.,  50.,   0.],
#          [ 20.,  53.,   6.],
#          ...,
#          [101., 142.,  74.],
#          [110., 151.,  83.],
#          [115., 156.,  86.]],
#
#         [[ 32.,  60.,   9.],
#          [ 30.,  60.,   8.],
#          [ 32.,  61.,  13.],
#          ...,
#          [118., 155.,  85.],
#          [121., 158.,  88.],
#          [122., 162.,  89.]],
#
#         ...,
#
#         [[124., 173., 107.],
#          [112., 161.,  95.],
#          [ 99., 146.,  78.],
#          ...,
#          [128., 156., 116.],
#          [ 80., 101.,  70.],
#          [ 84., 105.,  74.]],
#
#         [[126., 175., 109.],
#          [121., 170., 104.],
#          [105., 152.,  84.],
#          ...,
#          [104., 128.,  94.],
#          [ 75.,  91.,  65.],
#          [ 82.,  98.,  72.]],
#
#         [[129., 178., 112.],
#          [122., 171., 105.],
#          [102., 149.,  81.],
#          ...,
#          [107., 131.,  97.],
#          [ 79.,  95.,  69.],
#          [ 84.,  98.,  75.]]],
#
#
#        [[[111., 155.,  92.],
#          [112., 156.,  93.],
#          [117., 161.,  98.],
#          ...,
#          [152., 198., 149.],
#          [118., 165., 111.],
#          [123., 170., 115.]],
#
#         [[124., 169., 104.],
#          [125., 170., 105.],
#          [127., 171., 108.],
#          ...,
#          [143., 190., 138.],
#          [124., 171., 116.],
#          [119., 167., 109.]],
#
#         [[120., 166.,  94.],
#          [122., 168.,  96.],
#          [130., 175., 106.],
#          ...,
#          [125., 173., 115.],
#          [126., 174., 112.],
#          [110., 158.,  96.]],
#
#         ...,
#
#         [[131., 185., 101.],
#          [129., 183.,  99.],
#          [116., 169.,  89.],
#          ...,
#          [109., 158., 103.],
#          [ 20.,  67.,  13.],
#          [ 33.,  80.,  26.]],
#
#         [[108., 162.,  74.],
#          [105., 159.,  71.],
#          [104., 158.,  74.],
#          ...,
#          [ 70., 117.,  63.],
#          [ 23.,  70.,  16.],
#          [ 34.,  81.,  27.]],
#
#         [[107., 162.,  71.],
#          [104., 159.,  68.],
#          [101., 155.,  71.],
#          ...,
#          [ 60., 107.,  53.],
#          [ 16.,  63.,   9.],
#          [ 30.,  77.,  23.]]],
#
#
#        ...,
#
#
#        [[[ 50.,  35.,  40.],
#          [ 46.,  31.,  36.],
#          [ 51.,  36.,  41.],
#          ...,
#          [126., 149.,  95.],
#          [ 38.,  53.,  20.],
#          [ 82.,  97.,  68.]],
#
#         [[ 49.,  34.,  39.],
#          [ 45.,  30.,  35.],
#          [ 59.,  44.,  49.],
#          ...,
#          [131., 154.,  98.],
#          [ 46.,  62.,  26.],
#          [ 67.,  82.,  51.]],
#
#         [[ 47.,  32.,  37.],
#          [ 43.,  28.,  33.],
#          [ 72.,  57.,  62.],
#          ...,
#          [146., 170., 110.],
#          [ 54.,  70.,  31.],
#          [ 47.,  63.,  27.]],
#
#         ...,
#
#         [[159., 198., 135.],
#          [151., 190., 125.],
#          [147., 188., 118.],
#          ...,
#          [154., 187., 132.],
#          [126., 168.,  96.],
#          [136., 180., 103.]],
#
#         [[156., 195., 130.],
#          [152., 191., 126.],
#          [145., 186., 116.],
#          ...,
#          [156., 189., 134.],
#          [128., 170.,  98.],
#          [132., 176.,  99.]],
#
#         [[152., 191., 126.],
#          [153., 192., 125.],
#          [147., 189., 117.],
#          ...,
#          [156., 189., 134.],
#          [125., 167.,  95.],
#          [125., 169.,  92.]]],
#
#
#        [[[ 37.,  66.,  20.],
#          [ 69.,  98.,  50.],
#          [125., 155., 103.],
#          ...,
#          [174., 209., 129.],
#          [180., 215., 135.],
#          [182., 217., 137.]],
#
#         [[ 18.,  47.,   1.],
#          [ 19.,  48.,   2.],
#          [ 20.,  50.,   0.],
#          ...,
#          [174., 209., 129.],
#          [181., 216., 136.],
#          [183., 218., 138.]],
#
#         [[ 51.,  76.,  34.],
#          [ 39.,  66.,  23.],
#          [ 37.,  65.,  17.],
#          ...,
#          [189., 223., 146.],
#          [191., 225., 148.],
#          [191., 225., 148.]],
#
#         ...,
#
#         [[ 52.,  53.,  39.],
#          [ 45.,  46.,  30.],
#          [ 41.,  46.,  23.],
#          ...,
#          [ 24.,  46.,  10.],
#          [ 24.,  43.,  11.],
#          [ 23.,  42.,  10.]],
#
#         [[ 49.,  47.,  32.],
#          [ 48.,  49.,  33.],
#          [ 38.,  43.,  20.],
#          ...,
#          [ 26.,  48.,  12.],
#          [ 25.,  44.,  12.],
#          [ 24.,  43.,  11.]],
#
#         [[ 48.,  46.,  31.],
#          [ 41.,  42.,  24.],
#          [ 62.,  67.,  44.],
#          ...,
#          [ 26.,  48.,  12.],
#          [ 26.,  45.,  13.],
#          [ 24.,  43.,  11.]]],
#
#
#        [[[105., 147.,  97.],
#          [107., 149.,  99.],
#          [109., 151., 101.],
#          ...,
#          [ 64.,  95.,  61.],
#          [181., 215., 180.],
#          [190., 224., 189.]],
#
#         [[103., 145.,  95.],
#          [105., 147.,  97.],
#          [108., 150., 100.],
#          ...,
#          [ 10.,  42.,   5.],
#          [110., 144., 107.],
#          [164., 198., 161.]],
#
#         [[107., 149.,  99.],
#          [109., 151., 101.],
#          [110., 152., 104.],
#          ...,
#          [ 39.,  72.,  27.],
#          [ 21.,  57.,  11.],
#          [127., 163., 117.]],
#
#         ...,
#
#         [[119., 181., 130.],
#          [131., 193., 142.],
#          [131., 199., 142.],
#          ...,
#          [134., 191., 136.],
#          [151., 209., 150.],
#          [150., 208., 147.]],
#
#         [[155., 215., 179.],
#          [147., 207., 171.],
#          [122., 187., 144.],
#          ...,
#          [111., 172., 112.],
#          [127., 189., 122.],
#          [132., 194., 127.]],
#
#         [[174., 233., 201.],
#          [166., 226., 192.],
#          [131., 196., 154.],
#          ...,
#          [112., 176., 115.],
#          [116., 178., 111.],
#          [116., 179., 109.]]]], dtype=float32)

# %%
ft_model.save('mobilenetv2_finetuned_NO_INVERSION')
