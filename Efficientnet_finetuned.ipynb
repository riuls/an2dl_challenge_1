# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Homework1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Homework1

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
import matplotlib.pyplot as plt
from random import randint

# %%
seed = 19
import os
import random

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
def load_data(folder="public_data.npz", resolution=96, head_only=False):
    images = []

    loaded = np.load(folder, allow_pickle=True)

    # Iterate through files in the specified folder
    for i, img in enumerate(loaded['data']):
        # Normalize image pixel values to a float range [0, 1]
        #img = (img / 255).astype(np.float32)

        # Convert image from BGR to RGB
        #img = img[...,::-1]

        # Make the image dataset squared
        dim = min(img.shape[:-1])
        img = img[(img.shape[0]-dim)//2:(img.shape[0]+dim)//2, (img.shape[1]-dim)//2:(img.shape[1]+dim)//2, :]

        # Resize the image to 224x224 pixels
        #img = tfkl.Resizing(224, 224)(img)
        img = tfkl.Resizing(resolution, resolution)(img)

        if img is not None:
            images.append(img)

        if (head_only and i == 9):
           break

    labels = loaded['labels']
    loaded.close()

    if (head_only):
       labels = labels[:10]

    y = LabelEncoder().fit_transform(labels)
    y = tfk.utils.to_categorical(y, 2)

    return np.array(images), y




def display_random_images(X, y, num_img=10):
  # Create subplots for displaying items
  fig, axes = plt.subplots(2, num_img//2, figsize=(20, 9))
  for i in range(num_img):
      image = randint(0, X.shape[0] - 1)

      ax = axes[i%2, i%num_img//2]
      ax.imshow(np.clip(X[image], 0, 255))  # Display clipped item images
      ax.text(0.5, -0.1, str(image) + ' ' + str(y[image]), size=12, ha="center", transform=ax.transAxes)
      ax.axis('off')
  plt.tight_layout()
  plt.show()




def delete_outliers(X, y):
  shrek = 137
  trololo = 5143

  new_X = []
  new_y = []

  num_outliers = 0

  for i, sample in enumerate(X):
    if (not (np.array_equal(sample, X[shrek]) or np.array_equal(sample, X[trololo]))):
      new_X.append(sample)
      new_y.append(y[i])
    else:
      num_outliers += 1

  return np.array(new_X), np.array(new_y), num_outliers

# %%
X, y = load_data('public_data.npz')
X, y, num_outliers = delete_outliers(X, y)

# %%
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=600, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train_0, y_val = train_test_split(X_train_val, y_train_val, test_size=600, stratify=np.argmax(y_train_val,axis=1))

print(X_train.shape, y_train_0.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3804, 96, 96, 3) (3804, 2)
# (600, 96, 96, 3) (600, 2)
# (600, 96, 96, 3) (600, 2)

# %%
augment1 = tf.keras.Sequential([
    tfkl.RandomFlip(),
    tfkl.RandomTranslation(height_factor = (-0.2,0.2), width_factor = (-0.2,0.2), fill_mode = 'reflect'),
    tfkl.RandomZoom(0.3, fill_mode = 'reflect'),
    tfkl.RandomBrightness(0.1, value_range=(0,255)),
])

augment2 = tf.keras.Sequential([
    tfkl.RandomFlip(),
    tfkl.RandomZoom(0.4, fill_mode = 'reflect'),
    tfkl.RandomBrightness(0.1, value_range=(0,255)),
    tfkl.RandomRotation((-1,1), fill_mode = 'reflect'),
])

new_X_train_1 = augment2(X_train[np.where((y_train_0[:, 0] == 0) & (y_train_0[:, 1] == 1))])
augmented_X_train_2 = augment2(X_train)
augmented_X_train_1 = augment1(augmented_X_train_2)

X_train = np.append(X_train ,augmented_X_train_2, axis = 0)
X_train = np.append(X_train ,augmented_X_train_1, axis = 0)
X_train = np.append(X_train ,new_X_train_1, axis = 0)

y_train = np.append(y_train_0, y_train_0, axis = 0)
y_train = np.append(y_train, y_train_0, axis = 0)
for k in range(new_X_train_1.shape[0]):
    y_train = np.append(y_train, [[0,1]], axis = 0)

# %%
# Define key model parameters
input_shape = X_train.shape[1:]  # Input shape for the model
output_shape = y_train.shape[1]  # Output shape for the model
batch_size = 16                # Batch size for training, always a power of 2!!
epochs = 400

# %%
mobile = tfk.applications.EfficientNetV2B0(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing = True
)
mobile.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 [==============================] - 0s 0us/step

# %%
inputs = tfk.Input(shape=input_shape)
# Connect MobileNetV2 to the input
x = mobile(inputs)
x = tfkl.Dropout(rate = 1/5)(x)
x = tfkl.Dense(64)(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Activation('relu')(x)
x = tfkl.Dropout(rate = 1/7)(x)
x = tfkl.Dense(16)(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Activation('relu')(x)
x = tfkl.Dropout(rate = 1/7)(x)
# Add a Dense layer with 2 units and softmax activation as the classifier
outputs = tfkl.Dense(2, activation='softmax')(x)

# Create a Model connecting input and output
model_1 = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model with Categorical Cross-Entropy loss and Adam optimizer
model_1.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.AdamW(learning_rate=1e-3, weight_decay=3e-5), metrics=['accuracy'])

# Display model summary
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-b0 (Functio  (None, 1280)              5919312
#  nal)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 64)                81984
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  activation (Activation)     (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 16)                1040
#
#  batch_normalization_1 (Bat  (None, 16)                64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 16)                0
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 6002690 (22.90 MB)
# Trainable params: 83218 (325.07 KB)
# Non-trainable params: 5919472 (22.58 MB)
# _________________________________________________________________

# %%
history = model_1.fit(
    x = X_train, # We need to apply the preprocessing thought for the MobileNetV2 network
    y = y_train,
    batch_size = 16,
    epochs = 400,
    validation_data = (X_val, y_val), # We need to apply the preprocessing thought for the MobileNetV2 network
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=30, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.9, patience = 8, min_lr = 2e-6)
    ]
).history
# Out:
# Epoch 1/400
# 804/804 [==============================] - 42s 26ms/step - loss: 0.5882 - accuracy: 0.6882 - val_loss: 0.3897 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 2/400
# 804/804 [==============================] - 16s 19ms/step - loss: 0.5171 - accuracy: 0.7450 - val_loss: 0.3766 - val_accuracy: 0.8183 - lr: 0.0010
# Epoch 3/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.4901 - accuracy: 0.7628 - val_loss: 0.3558 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 4/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.4800 - accuracy: 0.7709 - val_loss: 0.3480 - val_accuracy: 0.8567 - lr: 0.0010
# Epoch 5/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.4728 - accuracy: 0.7736 - val_loss: 0.3379 - val_accuracy: 0.8683 - lr: 0.0010
# Epoch 6/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.4611 - accuracy: 0.7830 - val_loss: 0.3403 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 7/400
# 804/804 [==============================] - 16s 19ms/step - loss: 0.4560 - accuracy: 0.7861 - val_loss: 0.3440 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 8/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.4442 - accuracy: 0.7938 - val_loss: 0.3329 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 9/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.4523 - accuracy: 0.7858 - val_loss: 0.3305 - val_accuracy: 0.8433 - lr: 0.0010
# Epoch 10/400
# 804/804 [==============================] - 14s 18ms/step - loss: 0.4419 - accuracy: 0.7929 - val_loss: 0.3175 - val_accuracy: 0.8533 - lr: 0.0010
# Epoch 11/400
# 804/804 [==============================] - 13s 17ms/step - loss: 0.4321 - accuracy: 0.8043 - val_loss: 0.3167 - val_accuracy: 0.8600 - lr: 0.0010
# Epoch 12/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.4284 - accuracy: 0.8029 - val_loss: 0.3133 - val_accuracy: 0.8700 - lr: 0.0010
# Epoch 13/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.4254 - accuracy: 0.8025 - val_loss: 0.3189 - val_accuracy: 0.8550 - lr: 0.0010
# Epoch 14/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.4186 - accuracy: 0.8085 - val_loss: 0.3264 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 15/400
# 804/804 [==============================] - 12s 15ms/step - loss: 0.4089 - accuracy: 0.8130 - val_loss: 0.3104 - val_accuracy: 0.8733 - lr: 0.0010
# Epoch 16/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.4113 - accuracy: 0.8131 - val_loss: 0.3174 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 17/400
# 804/804 [==============================] - 13s 17ms/step - loss: 0.4094 - accuracy: 0.8131 - val_loss: 0.3223 - val_accuracy: 0.8550 - lr: 0.0010
# Epoch 18/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.4072 - accuracy: 0.8157 - val_loss: 0.3083 - val_accuracy: 0.8533 - lr: 0.0010
# Epoch 19/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3988 - accuracy: 0.8200 - val_loss: 0.3137 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 20/400
# 804/804 [==============================] - 12s 15ms/step - loss: 0.4017 - accuracy: 0.8171 - val_loss: 0.3160 - val_accuracy: 0.8617 - lr: 0.0010
# Epoch 21/400
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3912 - accuracy: 0.8235 - val_loss: 0.3109 - val_accuracy: 0.8517 - lr: 0.0010
# Epoch 22/400
# 804/804 [==============================] - 13s 17ms/step - loss: 0.3958 - accuracy: 0.8221 - val_loss: 0.3072 - val_accuracy: 0.8600 - lr: 0.0010
# Epoch 23/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3926 - accuracy: 0.8256 - val_loss: 0.3092 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 24/400
# 804/804 [==============================] - 13s 17ms/step - loss: 0.3879 - accuracy: 0.8276 - val_loss: 0.2993 - val_accuracy: 0.8600 - lr: 9.0000e-04
# Epoch 25/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3766 - accuracy: 0.8284 - val_loss: 0.3090 - val_accuracy: 0.8567 - lr: 9.0000e-04
# Epoch 26/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3829 - accuracy: 0.8281 - val_loss: 0.3007 - val_accuracy: 0.8667 - lr: 9.0000e-04
# Epoch 27/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3819 - accuracy: 0.8351 - val_loss: 0.3117 - val_accuracy: 0.8633 - lr: 9.0000e-04
# Epoch 28/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3775 - accuracy: 0.8337 - val_loss: 0.3053 - val_accuracy: 0.8667 - lr: 9.0000e-04
# Epoch 29/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3681 - accuracy: 0.8319 - val_loss: 0.3095 - val_accuracy: 0.8667 - lr: 9.0000e-04
# Epoch 30/400
# 804/804 [==============================] - 16s 20ms/step - loss: 0.3739 - accuracy: 0.8361 - val_loss: 0.3094 - val_accuracy: 0.8617 - lr: 9.0000e-04
# Epoch 31/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3678 - accuracy: 0.8386 - val_loss: 0.3122 - val_accuracy: 0.8633 - lr: 9.0000e-04
# Epoch 32/400
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3687 - accuracy: 0.8374 - val_loss: 0.3119 - val_accuracy: 0.8633 - lr: 8.1000e-04
# Epoch 33/400
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3674 - accuracy: 0.8349 - val_loss: 0.3090 - val_accuracy: 0.8683 - lr: 8.1000e-04
# Epoch 34/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3588 - accuracy: 0.8422 - val_loss: 0.3296 - val_accuracy: 0.8533 - lr: 8.1000e-04
# Epoch 35/400
# 804/804 [==============================] - 15s 18ms/step - loss: 0.3604 - accuracy: 0.8456 - val_loss: 0.3062 - val_accuracy: 0.8633 - lr: 8.1000e-04
# Epoch 36/400
# 804/804 [==============================] - 14s 18ms/step - loss: 0.3580 - accuracy: 0.8437 - val_loss: 0.3185 - val_accuracy: 0.8583 - lr: 8.1000e-04
# Epoch 37/400
# 804/804 [==============================] - 15s 18ms/step - loss: 0.3608 - accuracy: 0.8414 - val_loss: 0.3044 - val_accuracy: 0.8633 - lr: 8.1000e-04
# Epoch 38/400
# 804/804 [==============================] - 24s 30ms/step - loss: 0.3562 - accuracy: 0.8463 - val_loss: 0.3001 - val_accuracy: 0.8517 - lr: 8.1000e-04
# Epoch 39/400
# 804/804 [==============================] - 18s 22ms/step - loss: 0.3559 - accuracy: 0.8443 - val_loss: 0.3117 - val_accuracy: 0.8600 - lr: 8.1000e-04
# Epoch 40/400
# 804/804 [==============================] - 18s 22ms/step - loss: 0.3576 - accuracy: 0.8440 - val_loss: 0.3074 - val_accuracy: 0.8517 - lr: 7.2900e-04
# Epoch 41/400
# 804/804 [==============================] - 16s 19ms/step - loss: 0.3541 - accuracy: 0.8477 - val_loss: 0.3060 - val_accuracy: 0.8600 - lr: 7.2900e-04
# Epoch 42/400
# 804/804 [==============================] - 16s 20ms/step - loss: 0.3436 - accuracy: 0.8512 - val_loss: 0.2985 - val_accuracy: 0.8583 - lr: 7.2900e-04
# Epoch 43/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3453 - accuracy: 0.8480 - val_loss: 0.2978 - val_accuracy: 0.8600 - lr: 7.2900e-04
# Epoch 44/400
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3355 - accuracy: 0.8533 - val_loss: 0.3122 - val_accuracy: 0.8650 - lr: 7.2900e-04
# Epoch 45/400
# 804/804 [==============================] - 13s 17ms/step - loss: 0.3495 - accuracy: 0.8484 - val_loss: 0.3080 - val_accuracy: 0.8533 - lr: 7.2900e-04

# %%
# Evaluate the model on the test set
test_accuracy = model_1.evaluate(X_test,y_test,verbose=0)[-1]
print('Test set accuracy %.4f' % test_accuracy)
# Out:
# Test set accuracy 0.8550

# %%
model_1.save('efficientnetv2b0_and_augmentation_NO_INVERSION')

# %%
del model_1

# %%
ft_model = tfk.models.load_model('efficientnetv2b0_and_augmentation_NO_INVERSION')

# %%
ft_model.get_layer('efficientnetv2-b0').trainable = True

# %%
ft_model.get_layer('efficientnetv2-b0').summary()
# Out:
# Model: "efficientnetv2-b0"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  rescaling (Rescaling)       (None, 96, 96, 3)            0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 96, 96, 3)            0         ['rescaling[0][0]']
#  on)
#
#  stem_conv (Conv2D)          (None, 48, 48, 32)           864       ['normalization[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 48, 48, 32)           128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 48, 48, 32)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 48, 48, 16)           4608      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 48, 48, 16)           64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 48, 48, 16)           0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block2a_expand_conv (Conv2  (None, 24, 24, 64)           9216      ['block1a_project_activation[0
#  D)                                                                 ][0]']
#
#  block2a_expand_bn (BatchNo  (None, 24, 24, 64)           256       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 24, 24, 64)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 24, 24, 32)           2048      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 24, 24, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 24, 24, 128)          36864     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 24, 24, 128)          512       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 24, 24, 128)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 24, 24, 32)           4096      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 24, 24, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 24, 24, 32)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 24, 24, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 12, 12, 128)          36864     ['block2b_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 12, 12, 128)          512       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 12, 12, 128)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 12, 12, 48)           6144      ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 12, 12, 48)           192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 12, 12, 192)          82944     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 12, 12, 192)          768       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 12, 12, 192)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 12, 12, 48)           9216      ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 12, 12, 48)           192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 12, 12, 48)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 12, 12, 48)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 12, 12, 192)          9216      ['block3b_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 12, 12, 192)          768       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 12, 12, 192)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 6, 6, 192)            1728      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 6, 6, 192)            768       ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 6, 6, 192)            0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 192)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             2316      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 192)            2496      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 6, 6, 192)            0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 6, 6, 96)             18432     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 6, 6, 96)             384       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 6, 6, 384)            36864     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 6, 6, 384)            1536      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 6, 6, 384)            0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 6, 6, 384)            3456      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 6, 6, 384)            1536      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 6, 6, 384)            0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 384)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 6, 6, 384)            0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 6, 6, 96)             36864     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 6, 6, 96)             384       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 6, 6, 96)             0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 6, 6, 96)             0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 6, 6, 384)            36864     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 6, 6, 384)            1536      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 6, 6, 384)            0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 6, 6, 384)            3456      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 6, 6, 384)            1536      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 6, 6, 384)            0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 384)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 6, 6, 384)            0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 6, 6, 96)             36864     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 6, 6, 96)             384       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 6, 6, 96)             0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 6, 6, 96)             0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 6, 6, 576)            55296     ['block4c_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 6, 6, 576)            2304      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 6, 6, 576)            0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 6, 6, 576)            5184      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 6, 6, 576)            2304      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 6, 6, 576)            0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 576)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 6, 6, 576)            0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 6, 6, 112)            64512     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 6, 6, 112)            448       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 6, 6, 672)            75264     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 6, 6, 672)            2688      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 6, 6, 672)            0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv2 (Depthwise  (None, 6, 6, 672)            6048      ['block5b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5b_bn (BatchNormaliza  (None, 6, 6, 672)            2688      ['block5b_dwconv2[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 6, 6, 672)            0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 672)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 6, 6, 672)            0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 6, 6, 112)            75264     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 6, 6, 112)            448       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 6, 6, 112)            0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 6, 6, 112)            0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 6, 6, 672)            75264     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 6, 6, 672)            2688      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 6, 6, 672)            0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv2 (Depthwise  (None, 6, 6, 672)            6048      ['block5c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5c_bn (BatchNormaliza  (None, 6, 6, 672)            2688      ['block5c_dwconv2[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 6, 6, 672)            0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 672)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 6, 6, 672)            0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 6, 6, 112)            75264     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 6, 6, 112)            448       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 6, 6, 112)            0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 6, 6, 112)            0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2  (None, 6, 6, 672)            75264     ['block5c_add[0][0]']
#  D)
#
#  block5d_expand_bn (BatchNo  (None, 6, 6, 672)            2688      ['block5d_expand_conv[0][0]']
#  rmalization)
#
#  block5d_expand_activation   (None, 6, 6, 672)            0         ['block5d_expand_bn[0][0]']
#  (Activation)
#
#  block5d_dwconv2 (Depthwise  (None, 6, 6, 672)            6048      ['block5d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5d_bn (BatchNormaliza  (None, 6, 6, 672)            2688      ['block5d_dwconv2[0][0]']
#  tion)
#
#  block5d_activation (Activa  (None, 6, 6, 672)            0         ['block5d_bn[0][0]']
#  tion)
#
#  block5d_se_squeeze (Global  (None, 672)                  0         ['block5d_activation[0][0]']
#  AveragePooling2D)
#
#  block5d_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5d_se_squeeze[0][0]']
#  e)
#
#  block5d_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5d_se_reshape[0][0]']
#
#  block5d_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5d_se_reduce[0][0]']
#
#  block5d_se_excite (Multipl  (None, 6, 6, 672)            0         ['block5d_activation[0][0]',
#  y)                                                                  'block5d_se_expand[0][0]']
#
#  block5d_project_conv (Conv  (None, 6, 6, 112)            75264     ['block5d_se_excite[0][0]']
#  2D)
#
#  block5d_project_bn (BatchN  (None, 6, 6, 112)            448       ['block5d_project_conv[0][0]']
#  ormalization)
#
#  block5d_drop (Dropout)      (None, 6, 6, 112)            0         ['block5d_project_bn[0][0]']
#
#  block5d_add (Add)           (None, 6, 6, 112)            0         ['block5d_drop[0][0]',
#                                                                      'block5c_add[0][0]']
#
#  block5e_expand_conv (Conv2  (None, 6, 6, 672)            75264     ['block5d_add[0][0]']
#  D)
#
#  block5e_expand_bn (BatchNo  (None, 6, 6, 672)            2688      ['block5e_expand_conv[0][0]']
#  rmalization)
#
#  block5e_expand_activation   (None, 6, 6, 672)            0         ['block5e_expand_bn[0][0]']
#  (Activation)
#
#  block5e_dwconv2 (Depthwise  (None, 6, 6, 672)            6048      ['block5e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5e_bn (BatchNormaliza  (None, 6, 6, 672)            2688      ['block5e_dwconv2[0][0]']
#  tion)
#
#  block5e_activation (Activa  (None, 6, 6, 672)            0         ['block5e_bn[0][0]']
#  tion)
#
#  block5e_se_squeeze (Global  (None, 672)                  0         ['block5e_activation[0][0]']
#  AveragePooling2D)
#
#  block5e_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5e_se_squeeze[0][0]']
#  e)
#
#  block5e_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5e_se_reshape[0][0]']
#
#  block5e_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5e_se_reduce[0][0]']
#
#  block5e_se_excite (Multipl  (None, 6, 6, 672)            0         ['block5e_activation[0][0]',
#  y)                                                                  'block5e_se_expand[0][0]']
#
#  block5e_project_conv (Conv  (None, 6, 6, 112)            75264     ['block5e_se_excite[0][0]']
#  2D)
#
#  block5e_project_bn (BatchN  (None, 6, 6, 112)            448       ['block5e_project_conv[0][0]']
#  ormalization)
#
#  block5e_drop (Dropout)      (None, 6, 6, 112)            0         ['block5e_project_bn[0][0]']
#
#  block5e_add (Add)           (None, 6, 6, 112)            0         ['block5e_drop[0][0]',
#                                                                      'block5d_add[0][0]']
#
#  block6a_expand_conv (Conv2  (None, 6, 6, 672)            75264     ['block5e_add[0][0]']
#  D)
#
#  block6a_expand_bn (BatchNo  (None, 6, 6, 672)            2688      ['block6a_expand_conv[0][0]']
#  rmalization)
#
#  block6a_expand_activation   (None, 6, 6, 672)            0         ['block6a_expand_bn[0][0]']
#  (Activation)
#
#  block6a_dwconv2 (Depthwise  (None, 3, 3, 672)            6048      ['block6a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6a_bn (BatchNormaliza  (None, 3, 3, 672)            2688      ['block6a_dwconv2[0][0]']
#  tion)
#
#  block6a_activation (Activa  (None, 3, 3, 672)            0         ['block6a_bn[0][0]']
#  tion)
#
#  block6a_se_squeeze (Global  (None, 672)                  0         ['block6a_activation[0][0]']
#  AveragePooling2D)
#
#  block6a_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block6a_se_squeeze[0][0]']
#  e)
#
#  block6a_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multipl  (None, 3, 3, 672)            0         ['block6a_activation[0][0]',
#  y)                                                                  'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv  (None, 3, 3, 192)            129024    ['block6a_se_excite[0][0]']
#  2D)
#
#  block6a_project_bn (BatchN  (None, 3, 3, 192)            768       ['block6a_project_conv[0][0]']
#  ormalization)
#
#  block6b_expand_conv (Conv2  (None, 3, 3, 1152)           221184    ['block6a_project_bn[0][0]']
#  D)
#
#  block6b_expand_bn (BatchNo  (None, 3, 3, 1152)           4608      ['block6b_expand_conv[0][0]']
#  rmalization)
#
#  block6b_expand_activation   (None, 3, 3, 1152)           0         ['block6b_expand_bn[0][0]']
#  (Activation)
#
#  block6b_dwconv2 (Depthwise  (None, 3, 3, 1152)           10368     ['block6b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6b_bn (BatchNormaliza  (None, 3, 3, 1152)           4608      ['block6b_dwconv2[0][0]']
#  tion)
#
#  block6b_activation (Activa  (None, 3, 3, 1152)           0         ['block6b_bn[0][0]']
#  tion)
#
#  block6b_se_squeeze (Global  (None, 1152)                 0         ['block6b_activation[0][0]']
#  AveragePooling2D)
#
#  block6b_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6b_se_squeeze[0][0]']
#  e)
#
# ...
#  block6e_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6e_se_squeeze[0][0]']
#  e)
#
#  block6e_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multipl  (None, 3, 3, 1152)           0         ['block6e_activation[0][0]',
#  y)                                                                  'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv  (None, 3, 3, 192)            221184    ['block6e_se_excite[0][0]']
#  2D)
#
#  block6e_project_bn (BatchN  (None, 3, 3, 192)            768       ['block6e_project_conv[0][0]']
#  ormalization)
#
#  block6e_drop (Dropout)      (None, 3, 3, 192)            0         ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)           (None, 3, 3, 192)            0         ['block6e_drop[0][0]',
#                                                                      'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2  (None, 3, 3, 1152)           221184    ['block6e_add[0][0]']
#  D)
#
#  block6f_expand_bn (BatchNo  (None, 3, 3, 1152)           4608      ['block6f_expand_conv[0][0]']
#  rmalization)
#
#  block6f_expand_activation   (None, 3, 3, 1152)           0         ['block6f_expand_bn[0][0]']
#  (Activation)
#
#  block6f_dwconv2 (Depthwise  (None, 3, 3, 1152)           10368     ['block6f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6f_bn (BatchNormaliza  (None, 3, 3, 1152)           4608      ['block6f_dwconv2[0][0]']
#  tion)
#
#  block6f_activation (Activa  (None, 3, 3, 1152)           0         ['block6f_bn[0][0]']
#  tion)
#
#  block6f_se_squeeze (Global  (None, 1152)                 0         ['block6f_activation[0][0]']
#  AveragePooling2D)
#
#  block6f_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6f_se_squeeze[0][0]']
#  e)
#
#  block6f_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multipl  (None, 3, 3, 1152)           0         ['block6f_activation[0][0]',
#  y)                                                                  'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv  (None, 3, 3, 192)            221184    ['block6f_se_excite[0][0]']
#  2D)
#
#  block6f_project_bn (BatchN  (None, 3, 3, 192)            768       ['block6f_project_conv[0][0]']
#  ormalization)
#
#  block6f_drop (Dropout)      (None, 3, 3, 192)            0         ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)           (None, 3, 3, 192)            0         ['block6f_drop[0][0]',
#                                                                      'block6e_add[0][0]']
#
#  block6g_expand_conv (Conv2  (None, 3, 3, 1152)           221184    ['block6f_add[0][0]']
#  D)
#
#  block6g_expand_bn (BatchNo  (None, 3, 3, 1152)           4608      ['block6g_expand_conv[0][0]']
#  rmalization)
#
#  block6g_expand_activation   (None, 3, 3, 1152)           0         ['block6g_expand_bn[0][0]']
#  (Activation)
#
#  block6g_dwconv2 (Depthwise  (None, 3, 3, 1152)           10368     ['block6g_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6g_bn (BatchNormaliza  (None, 3, 3, 1152)           4608      ['block6g_dwconv2[0][0]']
#  tion)
#
#  block6g_activation (Activa  (None, 3, 3, 1152)           0         ['block6g_bn[0][0]']
#  tion)
#
#  block6g_se_squeeze (Global  (None, 1152)                 0         ['block6g_activation[0][0]']
#  AveragePooling2D)
#
#  block6g_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6g_se_squeeze[0][0]']
#  e)
#
#  block6g_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multipl  (None, 3, 3, 1152)           0         ['block6g_activation[0][0]',
#  y)                                                                  'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv  (None, 3, 3, 192)            221184    ['block6g_se_excite[0][0]']
#  2D)
#
#  block6g_project_bn (BatchN  (None, 3, 3, 192)            768       ['block6g_project_conv[0][0]']
#  ormalization)
#
#  block6g_drop (Dropout)      (None, 3, 3, 192)            0         ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)           (None, 3, 3, 192)            0         ['block6g_drop[0][0]',
#                                                                      'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2  (None, 3, 3, 1152)           221184    ['block6g_add[0][0]']
#  D)
#
#  block6h_expand_bn (BatchNo  (None, 3, 3, 1152)           4608      ['block6h_expand_conv[0][0]']
#  rmalization)
#
#  block6h_expand_activation   (None, 3, 3, 1152)           0         ['block6h_expand_bn[0][0]']
#  (Activation)
#
#  block6h_dwconv2 (Depthwise  (None, 3, 3, 1152)           10368     ['block6h_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6h_bn (BatchNormaliza  (None, 3, 3, 1152)           4608      ['block6h_dwconv2[0][0]']
#  tion)
#
#  block6h_activation (Activa  (None, 3, 3, 1152)           0         ['block6h_bn[0][0]']
#  tion)
#
#  block6h_se_squeeze (Global  (None, 1152)                 0         ['block6h_activation[0][0]']
#  AveragePooling2D)
#
#  block6h_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6h_se_squeeze[0][0]']
#  e)
#
#  block6h_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multipl  (None, 3, 3, 1152)           0         ['block6h_activation[0][0]',
#  y)                                                                  'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv  (None, 3, 3, 192)            221184    ['block6h_se_excite[0][0]']
#  2D)
#
#  block6h_project_bn (BatchN  (None, 3, 3, 192)            768       ['block6h_project_conv[0][0]']
#  ormalization)
#
#  block6h_drop (Dropout)      (None, 3, 3, 192)            0         ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)           (None, 3, 3, 192)            0         ['block6h_drop[0][0]',
#                                                                      'block6g_add[0][0]']
#
#  top_conv (Conv2D)           (None, 3, 3, 1280)           245760    ['block6h_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 3, 3, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 3, 3, 1280)           0         ['top_bn[0][0]']
#  )
#
#  avg_pool (GlobalAveragePoo  (None, 1280)                 0         ['top_activation[0][0]']
#  ling2D)
#
# ==================================================================================================
# Total params: 5919312 (22.58 MB)
# Trainable params: 5858704 (22.35 MB)
# Non-trainable params: 60608 (236.75 KB)
# __________________________________________________________________________________________________

# %%
# Freeze first N layers
N = 34    # last block
for i, layer in enumerate(ft_model.get_layer('efficientnetv2-b0').layers[:-N]):
  layer.trainable=False

# %%
for i, layer in enumerate(ft_model.get_layer('efficientnetv2-b0').layers):
  print(layer.name, layer.trainable)
# Out:
# input_1 False
# rescaling False
# normalization False
# stem_conv False
# stem_bn False
# stem_activation False
# block1a_project_conv False
# block1a_project_bn False
# block1a_project_activation False
# block2a_expand_conv False
# block2a_expand_bn False
# block2a_expand_activation False
# block2a_project_conv False
# block2a_project_bn False
# block2b_expand_conv False
# block2b_expand_bn False
# block2b_expand_activation False
# block2b_project_conv False
# block2b_project_bn False
# block2b_drop False
# block2b_add False
# block3a_expand_conv False
# block3a_expand_bn False
# block3a_expand_activation False
# block3a_project_conv False
# block3a_project_bn False
# block3b_expand_conv False
# block3b_expand_bn False
# block3b_expand_activation False
# block3b_project_conv False
# block3b_project_bn False
# block3b_drop False
# block3b_add False
# block4a_expand_conv False
# block4a_expand_bn False
# block4a_expand_activation False
# block4a_dwconv2 False
# block4a_bn False
# block4a_activation False
# block4a_se_squeeze False
# block4a_se_reshape False
# block4a_se_reduce False
# block4a_se_expand False
# block4a_se_excite False
# block4a_project_conv False
# block4a_project_bn False
# block4b_expand_conv False
# block4b_expand_bn False
# block4b_expand_activation False
# block4b_dwconv2 False
# block4b_bn False
# block4b_activation False
# block4b_se_squeeze False
# block4b_se_reshape False
# block4b_se_reduce False
# block4b_se_expand False
# block4b_se_excite False
# block4b_project_conv False
# block4b_project_bn False
# block4b_drop False
# block4b_add False
# block4c_expand_conv False
# block4c_expand_bn False
# block4c_expand_activation False
# block4c_dwconv2 False
# block4c_bn False
# block4c_activation False
# block4c_se_squeeze False
# block4c_se_reshape False
# block4c_se_reduce False
# block4c_se_expand False
# block4c_se_excite False
# block4c_project_conv False
# block4c_project_bn False
# block4c_drop False
# block4c_add False
# block5a_expand_conv False
# block5a_expand_bn False
# block5a_expand_activation False
# block5a_dwconv2 False
# block5a_bn False
# block5a_activation False
# block5a_se_squeeze False
# block5a_se_reshape False
# block5a_se_reduce False
# block5a_se_expand False
# block5a_se_excite False
# block5a_project_conv False
# block5a_project_bn False
# block5b_expand_conv False
# block5b_expand_bn False
# block5b_expand_activation False
# block5b_dwconv2 False
# block5b_bn False
# block5b_activation False
# block5b_se_squeeze False
# block5b_se_reshape False
# block5b_se_reduce False
# block5b_se_expand False
# block5b_se_excite False
# block5b_project_conv False
# block5b_project_bn False
# block5b_drop False
# block5b_add False
# block5c_expand_conv False
# block5c_expand_bn False
# block5c_expand_activation False
# block5c_dwconv2 False
# block5c_bn False
# block5c_activation False
# block5c_se_squeeze False
# block5c_se_reshape False
# block5c_se_reduce False
# block5c_se_expand False
# block5c_se_excite False
# block5c_project_conv False
# block5c_project_bn False
# block5c_drop False
# block5c_add False
# block5d_expand_conv False
# block5d_expand_bn False
# block5d_expand_activation False
# block5d_dwconv2 False
# block5d_bn False
# block5d_activation False
# block5d_se_squeeze False
# block5d_se_reshape False
# block5d_se_reduce False
# block5d_se_expand False
# block5d_se_excite False
# block5d_project_conv False
# block5d_project_bn False
# block5d_drop False
# block5d_add False
# block5e_expand_conv False
# block5e_expand_bn False
# block5e_expand_activation False
# block5e_dwconv2 False
# block5e_bn False
# block5e_activation False
# block5e_se_squeeze False
# block5e_se_reshape False
# block5e_se_reduce False
# block5e_se_expand False
# block5e_se_excite False
# block5e_project_conv False
# block5e_project_bn False
# block5e_drop False
# block5e_add False
# block6a_expand_conv False
# block6a_expand_bn False
# block6a_expand_activation False
# block6a_dwconv2 False
# block6a_bn False
# block6a_activation False
# block6a_se_squeeze False
# block6a_se_reshape False
# block6a_se_reduce False
# block6a_se_expand False
# block6a_se_excite False
# block6a_project_conv False
# block6a_project_bn False
# block6b_expand_conv False
# block6b_expand_bn False
# block6b_expand_activation False
# block6b_dwconv2 False
# block6b_bn False
# block6b_activation False
# block6b_se_squeeze False
# block6b_se_reshape False
# block6b_se_reduce False
# block6b_se_expand False
# block6b_se_excite False
# block6b_project_conv False
# block6b_project_bn False
# block6b_drop False
# block6b_add False
# block6c_expand_conv False
# block6c_expand_bn False
# block6c_expand_activation False
# block6c_dwconv2 False
# block6c_bn False
# block6c_activation False
# block6c_se_squeeze False
# block6c_se_reshape False
# block6c_se_reduce False
# block6c_se_expand False
# block6c_se_excite False
# block6c_project_conv False
# block6c_project_bn False
# block6c_drop False
# block6c_add False
# block6d_expand_conv False
# block6d_expand_bn False
# block6d_expand_activation False
# block6d_dwconv2 False
# block6d_bn False
# block6d_activation False
# block6d_se_squeeze False
# block6d_se_reshape False
# block6d_se_reduce False
# block6d_se_expand False
# block6d_se_excite False
# block6d_project_conv False
# block6d_project_bn False
# block6d_drop False
# block6d_add False
# block6e_expand_conv False
# block6e_expand_bn False
# block6e_expand_activation False
# block6e_dwconv2 False
# block6e_bn False
# block6e_activation False
# block6e_se_squeeze False
# block6e_se_reshape False
# block6e_se_reduce False
# block6e_se_expand False
# block6e_se_excite False
# block6e_project_conv False
# block6e_project_bn False
# block6e_drop False
# block6e_add False
# block6f_expand_conv False
# block6f_expand_bn False
# block6f_expand_activation False
# block6f_dwconv2 False
# block6f_bn False
# block6f_activation False
# block6f_se_squeeze False
# block6f_se_reshape False
# block6f_se_reduce False
# block6f_se_expand False
# block6f_se_excite False
# block6f_project_conv False
# block6f_project_bn False
# block6f_drop False
# block6f_add False
# block6g_expand_conv True
# block6g_expand_bn True
# block6g_expand_activation True
# block6g_dwconv2 True
# block6g_bn True
# block6g_activation True
# block6g_se_squeeze True
# block6g_se_reshape True
# block6g_se_reduce True
# block6g_se_expand True
# block6g_se_excite True
# block6g_project_conv True
# block6g_project_bn True
# block6g_drop True
# block6g_add True
# block6h_expand_conv True
# block6h_expand_bn True
# block6h_expand_activation True
# block6h_dwconv2 True
# block6h_bn True
# block6h_activation True
# block6h_se_squeeze True
# block6h_se_reshape True
# block6h_se_reduce True
# block6h_se_expand True
# block6h_se_excite True
# block6h_project_conv True
# block6h_project_bn True
# block6h_drop True
# block6h_add True
# top_conv True
# top_bn True
# top_activation True
# avg_pool True

# %%
ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.AdamW(), metrics='accuracy')

# %%
history = ft_model.fit(
    x = X_train, # We need to apply the preprocessing thought for the MobileNetV2 network
    y = y_train,
    batch_size = 16,
    epochs = 400,
    validation_data = (X_val, y_val), # We need to apply the preprocessing thought for the MobileNetV2 network
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=30, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.9, patience = 8, min_lr = 2e-6)
    ]
).history
# Out:
# Epoch 1/400
# 804/804 [==============================] - 37s 28ms/step - loss: 0.5023 - accuracy: 0.7606 - val_loss: 0.3145 - val_accuracy: 0.8633 - lr: 0.0010
# Epoch 2/400
# 804/804 [==============================] - 22s 27ms/step - loss: 0.4102 - accuracy: 0.8179 - val_loss: 0.3032 - val_accuracy: 0.8533 - lr: 0.0010
# Epoch 3/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.3526 - accuracy: 0.8506 - val_loss: 0.2957 - val_accuracy: 0.8683 - lr: 0.0010
# Epoch 4/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.3238 - accuracy: 0.8632 - val_loss: 0.3143 - val_accuracy: 0.8583 - lr: 0.0010
# Epoch 5/400
# 804/804 [==============================] - 23s 28ms/step - loss: 0.2941 - accuracy: 0.8788 - val_loss: 0.3518 - val_accuracy: 0.8517 - lr: 0.0010
# Epoch 6/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.2648 - accuracy: 0.8943 - val_loss: 0.3267 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 7/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.2445 - accuracy: 0.9052 - val_loss: 0.3832 - val_accuracy: 0.8517 - lr: 0.0010
# Epoch 8/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.2116 - accuracy: 0.9175 - val_loss: 0.3447 - val_accuracy: 0.8817 - lr: 0.0010
# Epoch 9/400
# 804/804 [==============================] - 21s 27ms/step - loss: 0.2047 - accuracy: 0.9192 - val_loss: 0.3563 - val_accuracy: 0.8783 - lr: 0.0010
# Epoch 10/400
# 804/804 [==============================] - 21s 27ms/step - loss: 0.1908 - accuracy: 0.9257 - val_loss: 0.3335 - val_accuracy: 0.8833 - lr: 0.0010
# Epoch 11/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.1731 - accuracy: 0.9350 - val_loss: 0.3478 - val_accuracy: 0.8817 - lr: 0.0010
# Epoch 12/400
# 804/804 [==============================] - 22s 27ms/step - loss: 0.1692 - accuracy: 0.9348 - val_loss: 0.3547 - val_accuracy: 0.8783 - lr: 0.0010
# Epoch 13/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.1503 - accuracy: 0.9456 - val_loss: 0.4757 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 14/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.1451 - accuracy: 0.9446 - val_loss: 0.3824 - val_accuracy: 0.8783 - lr: 0.0010
# Epoch 15/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.1326 - accuracy: 0.9512 - val_loss: 0.3778 - val_accuracy: 0.8700 - lr: 0.0010
# Epoch 16/400
# 804/804 [==============================] - 22s 28ms/step - loss: 0.1362 - accuracy: 0.9505 - val_loss: 0.3755 - val_accuracy: 0.8767 - lr: 0.0010
# Epoch 17/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.1310 - accuracy: 0.9532 - val_loss: 0.3875 - val_accuracy: 0.8717 - lr: 0.0010
# Epoch 18/400
# 804/804 [==============================] - 20s 24ms/step - loss: 0.1084 - accuracy: 0.9627 - val_loss: 0.4645 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 19/400
# 804/804 [==============================] - 23s 28ms/step - loss: 0.1129 - accuracy: 0.9579 - val_loss: 0.4264 - val_accuracy: 0.8817 - lr: 9.0000e-04
# Epoch 20/400
# 804/804 [==============================] - 22s 28ms/step - loss: 0.1000 - accuracy: 0.9645 - val_loss: 0.4616 - val_accuracy: 0.8733 - lr: 9.0000e-04
# Epoch 21/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0940 - accuracy: 0.9659 - val_loss: 0.4020 - val_accuracy: 0.8783 - lr: 9.0000e-04
# Epoch 22/400
# 804/804 [==============================] - 22s 27ms/step - loss: 0.0982 - accuracy: 0.9658 - val_loss: 0.4548 - val_accuracy: 0.8800 - lr: 9.0000e-04
# Epoch 23/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0878 - accuracy: 0.9675 - val_loss: 0.4049 - val_accuracy: 0.8883 - lr: 9.0000e-04
# Epoch 24/400
# 804/804 [==============================] - 23s 28ms/step - loss: 0.0927 - accuracy: 0.9670 - val_loss: 0.4356 - val_accuracy: 0.8750 - lr: 9.0000e-04
# Epoch 25/400
# 804/804 [==============================] - 22s 28ms/step - loss: 0.0826 - accuracy: 0.9712 - val_loss: 0.4145 - val_accuracy: 0.8833 - lr: 9.0000e-04
# Epoch 26/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0894 - accuracy: 0.9708 - val_loss: 0.4560 - val_accuracy: 0.8767 - lr: 9.0000e-04
# Epoch 27/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.0852 - accuracy: 0.9712 - val_loss: 0.3994 - val_accuracy: 0.8767 - lr: 9.0000e-04
# Epoch 28/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0725 - accuracy: 0.9735 - val_loss: 0.4805 - val_accuracy: 0.8667 - lr: 9.0000e-04
# Epoch 29/400
# 804/804 [==============================] - 20s 24ms/step - loss: 0.0705 - accuracy: 0.9747 - val_loss: 0.4541 - val_accuracy: 0.8817 - lr: 9.0000e-04
# Epoch 30/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0833 - accuracy: 0.9718 - val_loss: 0.4169 - val_accuracy: 0.8917 - lr: 9.0000e-04
# Epoch 31/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0696 - accuracy: 0.9745 - val_loss: 0.4601 - val_accuracy: 0.8800 - lr: 9.0000e-04
# Epoch 32/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0703 - accuracy: 0.9769 - val_loss: 0.5037 - val_accuracy: 0.8817 - lr: 9.0000e-04
# Epoch 33/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0634 - accuracy: 0.9769 - val_loss: 0.4671 - val_accuracy: 0.8717 - lr: 9.0000e-04
# Epoch 34/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0653 - accuracy: 0.9781 - val_loss: 0.5157 - val_accuracy: 0.8817 - lr: 9.0000e-04
# Epoch 35/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0683 - accuracy: 0.9764 - val_loss: 0.4845 - val_accuracy: 0.8867 - lr: 9.0000e-04
# Epoch 36/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0711 - accuracy: 0.9758 - val_loss: 0.4801 - val_accuracy: 0.8833 - lr: 9.0000e-04
# Epoch 37/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.0637 - accuracy: 0.9792 - val_loss: 0.4649 - val_accuracy: 0.8800 - lr: 9.0000e-04
# Epoch 38/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.0629 - accuracy: 0.9778 - val_loss: 0.5446 - val_accuracy: 0.8817 - lr: 9.0000e-04
# Epoch 39/400
# 804/804 [==============================] - 22s 27ms/step - loss: 0.0605 - accuracy: 0.9799 - val_loss: 0.4741 - val_accuracy: 0.8683 - lr: 8.1000e-04
# Epoch 40/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0590 - accuracy: 0.9789 - val_loss: 0.4770 - val_accuracy: 0.8817 - lr: 8.1000e-04
# Epoch 41/400
# 804/804 [==============================] - 20s 24ms/step - loss: 0.0624 - accuracy: 0.9781 - val_loss: 0.4145 - val_accuracy: 0.8883 - lr: 8.1000e-04
# Epoch 42/400
# 804/804 [==============================] - 20s 24ms/step - loss: 0.0536 - accuracy: 0.9809 - val_loss: 0.5088 - val_accuracy: 0.8700 - lr: 8.1000e-04
# Epoch 43/400
# 804/804 [==============================] - 22s 27ms/step - loss: 0.0477 - accuracy: 0.9837 - val_loss: 0.4460 - val_accuracy: 0.8900 - lr: 8.1000e-04
# Epoch 44/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0479 - accuracy: 0.9831 - val_loss: 0.5846 - val_accuracy: 0.8783 - lr: 8.1000e-04
# Epoch 45/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0559 - accuracy: 0.9807 - val_loss: 0.4625 - val_accuracy: 0.8817 - lr: 8.1000e-04
# Epoch 46/400
# 804/804 [==============================] - 21s 27ms/step - loss: 0.0511 - accuracy: 0.9815 - val_loss: 0.4488 - val_accuracy: 0.8850 - lr: 8.1000e-04
# Epoch 47/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0499 - accuracy: 0.9834 - val_loss: 0.4329 - val_accuracy: 0.8783 - lr: 7.2900e-04
# Epoch 48/400
# 804/804 [==============================] - 36s 45ms/step - loss: 0.0441 - accuracy: 0.9847 - val_loss: 0.4447 - val_accuracy: 0.8917 - lr: 7.2900e-04
# Epoch 49/400
# 804/804 [==============================] - 26s 32ms/step - loss: 0.0449 - accuracy: 0.9849 - val_loss: 0.4945 - val_accuracy: 0.8767 - lr: 7.2900e-04
# Epoch 50/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0459 - accuracy: 0.9858 - val_loss: 0.5068 - val_accuracy: 0.8900 - lr: 7.2900e-04
# Epoch 51/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0434 - accuracy: 0.9843 - val_loss: 0.4805 - val_accuracy: 0.8850 - lr: 7.2900e-04
# Epoch 52/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0556 - accuracy: 0.9823 - val_loss: 0.4334 - val_accuracy: 0.8900 - lr: 7.2900e-04
# Epoch 53/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0452 - accuracy: 0.9856 - val_loss: 0.4353 - val_accuracy: 0.9033 - lr: 7.2900e-04
# Epoch 54/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.0370 - accuracy: 0.9872 - val_loss: 0.4466 - val_accuracy: 0.8883 - lr: 7.2900e-04
# Epoch 55/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0367 - accuracy: 0.9879 - val_loss: 0.4022 - val_accuracy: 0.8933 - lr: 7.2900e-04
# Epoch 56/400
# 804/804 [==============================] - 23s 29ms/step - loss: 0.0382 - accuracy: 0.9869 - val_loss: 0.5028 - val_accuracy: 0.8817 - lr: 7.2900e-04
# Epoch 57/400
# 804/804 [==============================] - 19s 24ms/step - loss: 0.0458 - accuracy: 0.9837 - val_loss: 0.4600 - val_accuracy: 0.8817 - lr: 7.2900e-04
# Epoch 58/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0340 - accuracy: 0.9890 - val_loss: 0.4657 - val_accuracy: 0.8883 - lr: 7.2900e-04
# Epoch 59/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0403 - accuracy: 0.9867 - val_loss: 0.5434 - val_accuracy: 0.8967 - lr: 7.2900e-04
# Epoch 60/400
# 804/804 [==============================] - 22s 27ms/step - loss: 0.0376 - accuracy: 0.9869 - val_loss: 0.4964 - val_accuracy: 0.8917 - lr: 7.2900e-04
# Epoch 61/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0414 - accuracy: 0.9851 - val_loss: 0.4817 - val_accuracy: 0.8833 - lr: 7.2900e-04
# Epoch 62/400
# 804/804 [==============================] - 20s 24ms/step - loss: 0.0332 - accuracy: 0.9883 - val_loss: 0.5095 - val_accuracy: 0.8850 - lr: 6.5610e-04
# Epoch 63/400
# 804/804 [==============================] - 24s 30ms/step - loss: 0.0379 - accuracy: 0.9877 - val_loss: 0.5712 - val_accuracy: 0.8733 - lr: 6.5610e-04
# Epoch 64/400
# 804/804 [==============================] - 20s 24ms/step - loss: 0.0372 - accuracy: 0.9870 - val_loss: 0.5287 - val_accuracy: 0.8700 - lr: 6.5610e-04
# Epoch 65/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0299 - accuracy: 0.9895 - val_loss: 0.5681 - val_accuracy: 0.8900 - lr: 6.5610e-04
# Epoch 66/400
# 804/804 [==============================] - 21s 27ms/step - loss: 0.0328 - accuracy: 0.9894 - val_loss: 0.6871 - val_accuracy: 0.8733 - lr: 6.5610e-04
# Epoch 67/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0338 - accuracy: 0.9886 - val_loss: 0.5693 - val_accuracy: 0.8917 - lr: 6.5610e-04
# Epoch 68/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0309 - accuracy: 0.9897 - val_loss: 0.5673 - val_accuracy: 0.8817 - lr: 6.5610e-04
# Epoch 69/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0380 - accuracy: 0.9880 - val_loss: 0.6057 - val_accuracy: 0.8800 - lr: 6.5610e-04
# Epoch 70/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0329 - accuracy: 0.9880 - val_loss: 0.6056 - val_accuracy: 0.8667 - lr: 5.9049e-04
# Epoch 71/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0306 - accuracy: 0.9904 - val_loss: 0.6677 - val_accuracy: 0.8717 - lr: 5.9049e-04
# Epoch 72/400
# 804/804 [==============================] - 20s 24ms/step - loss: 0.0278 - accuracy: 0.9900 - val_loss: 0.6337 - val_accuracy: 0.8633 - lr: 5.9049e-04
# Epoch 73/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0273 - accuracy: 0.9910 - val_loss: 0.6275 - val_accuracy: 0.8717 - lr: 5.9049e-04
# Epoch 74/400
# 804/804 [==============================] - 22s 27ms/step - loss: 0.0291 - accuracy: 0.9897 - val_loss: 0.6125 - val_accuracy: 0.8833 - lr: 5.9049e-04
# Epoch 75/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0294 - accuracy: 0.9904 - val_loss: 0.6283 - val_accuracy: 0.8717 - lr: 5.9049e-04
# Epoch 76/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0300 - accuracy: 0.9904 - val_loss: 0.5869 - val_accuracy: 0.8717 - lr: 5.9049e-04
# Epoch 77/400
# 804/804 [==============================] - 25s 30ms/step - loss: 0.0338 - accuracy: 0.9902 - val_loss: 0.5758 - val_accuracy: 0.8767 - lr: 5.9049e-04
# Epoch 78/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0345 - accuracy: 0.9900 - val_loss: 0.5495 - val_accuracy: 0.8783 - lr: 5.3144e-04
# Epoch 79/400
# 804/804 [==============================] - 20s 25ms/step - loss: 0.0278 - accuracy: 0.9904 - val_loss: 0.5404 - val_accuracy: 0.8700 - lr: 5.3144e-04
# Epoch 80/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0327 - accuracy: 0.9897 - val_loss: 0.5704 - val_accuracy: 0.8700 - lr: 5.3144e-04
# Epoch 81/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0280 - accuracy: 0.9907 - val_loss: 0.5553 - val_accuracy: 0.8733 - lr: 5.3144e-04
# Epoch 82/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0217 - accuracy: 0.9918 - val_loss: 0.5970 - val_accuracy: 0.8667 - lr: 5.3144e-04
# Epoch 83/400
# 804/804 [==============================] - 21s 26ms/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.6412 - val_accuracy: 0.8650 - lr: 5.3144e-04

# %%
# Evaluate the model on the test set
test_accuracy = ft_model.evaluate(X_test,y_test,verbose=0)[-1]
print('Test set accuracy %.4f' % test_accuracy)
# Out:
# Test set accuracy 0.8783

# %%
ft_model.save('Efficientnet_finetuned_NO_INVERSION')
